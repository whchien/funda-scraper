# %%
import os
import pandas as pd
import requests
from bs4 import BeautifulSoup
from typing import List, Dict
import datetime
from tqdm import tqdm
from tqdm.contrib.concurrent import process_map
from funda_scraper.config.core import config

os.chdir("/Users/willchien/PycharmProjects/funda-scraper")

# %%
from funda_scraper import FundaScraper

# %%
scraper = FundaScraper(area="utrecht", want_to="buy", find_past=True, n_pages=4)
df = scraper.run(raw_data=False, save=False)
df.shape
# Out:
# 2023-07-23 17:01:58,703 - INFO - *** Phase 1: Fetch all the available links from all pages ***  (scrape.py:110)
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:03<00:00,  1.52it/s]
# 2023-07-23 17:02:02,016 - INFO - *** Got all the urls. 60 houses found in 4 pages. *** (scrape.py:120)
# 2023-07-23 17:02:02,016 - INFO - *** Phase 2: Start scraping results from individual links *** (scrape.py:195)
#   0%|          | 0/60 [00:00<?, ?it/s]
# 2023-07-23 17:02:15,136 - INFO - *** All scraping done: 60 results *** (scrape.py:207)
# 2023-07-23 17:02:15,138 - INFO - *** Cleaning data *** (scrape.py:248)
# 2023-07-23 17:02:15,161 - INFO - *** Done! *** (scrape.py:255)
# (60, 25)

# %%
df
# Out:
#     house_id     city   house_type   building_type   price  price_m2 room  \
# 0   42266293  utrecht         huis  Bestaande bouw  419000    5371.8    4
# 1   42144399  utrecht         huis  Bestaande bouw  425000    4829.5    3
# 2   42143985  utrecht  appartement  Bestaande bouw  325000    4779.4    3
# 3   42257966  utrecht         huis  Bestaande bouw  625000    5208.3    7
# 4   42149513  utrecht  appartement  Bestaande bouw  389000    4862.5    3
# 5   42149814  utrecht         huis  Bestaande bouw  355000    3550.0    4
# 6   42877053  utrecht  appartement       Nieuwbouw  416500    6611.1    3
# 7   42149265  utrecht         huis  Bestaande bouw  769000    6103.2    7
# 8   42885449  utrecht         huis       Nieuwbouw  815000    5191.1    6
# 9   42143422  utrecht  appartement  Bestaande bouw  450000    5487.8    3
# 10  42877185  utrecht  appartement       Nieuwbouw  355000    6339.3    2
# 11  42877032  utrecht  appartement       Nieuwbouw  419000    6650.8    3
# 12  42877160  utrecht  appartement       Nieuwbouw  355000    6339.3    2
# 13  42877170  utrecht  appartement       Nieuwbouw  538000    6329.4    3
# 14  42048202  utrecht         huis       Nieuwbouw  825000    5221.5    6
# 15  42877162  utrecht  appartement       Nieuwbouw  532500    6574.1    3
# 16  42877051  utrecht  appartement       Nieuwbouw  421500    6690.5    3
# 17  42257080  utrecht  appartement  Bestaande bouw  675000    5443.5    4
# 18  42144987  utrecht  appartement  Bestaande bouw  375000    5769.2    4
# 19  42255744  utrecht  appartement  Bestaande bouw  275000    4104.5    2
# 20  42143050  utrecht  appartement  Bestaande bouw  315000    6057.7    2
# 21  42257970  utrecht         huis  Bestaande bouw  569500    4156.9    5
# 22  42877049  utrecht  appartement       Nieuwbouw  355000    6574.1    2
# 23  42931426  utrecht         huis       Nieuwbouw  820000    5222.9    6
# 24  42144972  utrecht         huis  Bestaande bouw  400000    5633.8    4
# 25  42142898  utrecht  appartement  Bestaande bouw  275000    5729.2    2
# 26  42877055  utrecht  appartement       Nieuwbouw  355000    6574.1    2
# 27  42257008  utrecht  appartement  Bestaande bouw  300000    4166.7    3
# 28  42144826  utrecht         huis  Bestaande bouw  499000    4940.6    5
# 29  42877189  utrecht  appartement       Nieuwbouw  355000    6339.3    2
# 30  42256131  utrecht  appartement  Bestaande bouw  349000    4985.7    2
# 31  42259838  utrecht  appartement  Bestaande bouw  800000    5970.1    5
# 32  42141561  utrecht         huis  Bestaande bouw  695000    6043.5    4
# 33  42142613  utrecht  appartement  Bestaande bouw  435000    4728.3    4
# 34  42143539  utrecht         huis  Bestaande bouw  650000    4924.2    7
# 35  42877176  utrecht  appartement       Nieuwbouw  497500    6546.1    3
# 36  42258164  utrecht  appartement  Bestaande bouw  385000    5923.1    2
# 37  42258976  utrecht         huis  Bestaande bouw  399000    6435.5    3
# 38  42149479  utrecht  appartement  Bestaande bouw  389500    4529.1    3
# 39  42255170  utrecht  appartement  Bestaande bouw  600000    5825.2    4
# 40  42266560  utrecht  appartement  Bestaande bouw  275000    3873.2    4
# 41  42265631  utrecht  appartement  Bestaande bouw  289000    3440.5    4
# 42  42877165  utrecht  appartement       Nieuwbouw  355000    6339.3    2
# 43  42266679  utrecht  appartement  Bestaande bouw  395000    5064.1    3
# 44  42877057  utrecht  appartement       Nieuwbouw  355000    6574.1    2
# 45  42252808  utrecht  appartement  Bestaande bouw  475000    4523.8    3
# 46  42885420  utrecht         huis       Nieuwbouw  825000    5221.5    6
# 47  42144023  utrecht  appartement  Bestaande bouw  315000    5943.4    2
# 48  42255506  utrecht  appartement  Bestaande bouw  250000    7575.8    2
# 49  42877040  utrecht  appartement       Nieuwbouw  424000    6730.2    3
# 50  42931573  utrecht         huis       Nieuwbouw  825000    5254.8    6
# 51  42877101  utrecht  appartement       Nieuwbouw  653500    6050.9    4
# 52  42149286  utrecht         huis  Bestaande bouw  400000    5714.3    3
# 53  42148834  utrecht  appartement  Bestaande bouw  200000    5263.2    2
# 54  41397545  utrecht  appartement       Nieuwbouw  775500    5423.1    4
# 55  42877168  utrecht  appartement       Nieuwbouw  545500    6417.6    3
# 56  42931435  utrecht         huis       Nieuwbouw  815000    5191.1    6
# 57  42930955  utrecht         huis       Nieuwbouw  960000    5393.3    7
# 58  42877166  utrecht  appartement       Nieuwbouw  548000    6447.1    3
# 59  42268066  utrecht  appartement  Bestaande bouw  235000    5108.7    3
#
#    bedroom bathroom  living_area  ... year_built  house_age  date_list  \
# 0        3        1           78  ...       1988         35 2023-06-30
# 1        2        1           88  ...       2000         23 2023-06-20
# 2        2        1           68  ...       1958         65 2023-06-16
# 3        6        1          120  ...       1927         96 2023-06-22
# 4        2        1           80  ...       1992         31 2023-06-15
# 5        3        1          100  ...       1918        105 2023-06-15
# 6        2        1           63  ...       2023          0 2022-07-01
# 7        5        2          126  ...       1931         92 2023-06-14
# 8        4        1          157  ...       2023          0 2022-07-07
# 9        2        1           82  ...       2002         21 2023-06-17
# 10       1        1           56  ...       2023          0 2022-07-01
# 11       2        1           63  ...       2023          0 2022-07-01
# 12       1        1           56  ...       2023          0 2022-07-01
# 13       2        1           85  ...       2023          0 2022-07-01
# 14       4        1          158  ...       2023          0 2023-03-10
# 15       2        1           81  ...       2023          0 2022-07-01
# 16       2        1           63  ...       2023          0 2022-07-01
# 17       3        1          124  ...       2018          5 2023-06-21
# 18       2        1           65  ...       1930         93 2023-06-20
# 19       1        1           67  ...       1926         97 2023-06-20
# 20       1        1           52  ...       2009         14 2023-06-16
# 21       4        1          137  ...       2015          8 2023-06-22
# 22       1        1           54  ...       2023          0 2022-07-01
# 23       4        1          157  ...       2023          0 2022-11-18
# 24       3        1           71  ...       1928         95 2023-06-20
# 25       1        1           48  ...       1927         96 2023-06-19
# 26       1        1           54  ...       2023          0 2022-07-01
# 27       2        1           72  ...       1964         59 2023-06-23
# 28       3        1          101  ...       1926         97 2023-06-21
# 29       1        1           56  ...       2023          0 2022-07-01
# 30       1        1           70  ...       2009         14 2023-06-22
# 31       4        1          134  ...       1928         95 2023-06-23
# 32       3        1          115  ...       1890        133 2023-06-16
# 33       3        1           92  ...       1930         93 2023-06-17
# 34       6        2          132  ...       1954         69 2023-06-19
# 35       2        1           76  ...       2023          0 2022-07-01
# 36       1        1           65  ...       2002         21 2023-06-22
# 37       2        1           62  ...       1945         78 2023-06-22
# 38       2        1           86  ...       1993         30 2023-06-13
# 39       3        1          103  ...       2008         15 2023-06-20
# 40       3        1           71  ...       1966         57 2023-06-29
# 41       3        1           84  ...       1966         57 2023-06-29
# 42       1        1           56  ...       2023          0 2022-07-01
# 43       2        1           78  ...       1931         92 2023-06-29
# 44       1        1           54  ...       2023          0 2022-07-01
# 45       2        1          105  ...       2006         17 2023-06-27
# 46       4        1          158  ...       2023          0 2022-07-07
# 47       1        1           53  ...       1931         92 2023-06-20
# 48       1        1           33  ...       1900        123 2023-06-21
# 49       2        1           63  ...       2023          0 2022-07-01
# 50       4        1          157  ...       2023          0 2022-11-18
# 51       3        1          108  ...       2023          0 2022-07-01
# 52       2        1           70  ...       1910        113 2023-06-15
# 53       1        1           38  ...       1960         63 2023-06-13
# 54       3        1          143  ...       2021          2 2021-04-23
# 55       2        1           85  ...       2023          0 2022-07-01
# 56       4        1          157  ...       2023          0 2022-11-18
# 57       5        1          178  ...       2023          0 2022-11-18
# 58       2        1           85  ...       2023          0 2022-07-01
# 59       2        1           46  ...       1919        104 2023-07-01
#
#       ym_list year_list                                            descrip  \
# 0  2023-06-01      2023  \r\nWelkom op de  Bertha  von Suttnerlaan!   *...
# 1  2023-06-01      2023  \r\nDeze moderne tussenwoning  is  gelegen op ...
# 2  2023-06-01      2023  \r\nOp de eerste  verdieping  van een  kleinsc...
# 3  2023-06-01      2023  \r\nVan Humboldtstraat 101:  Een  mooie energi...
# 4  2023-06-01      2023  \r\n** FOR ENGLISH  SEE  BELOW**  In de  rusti...
# 5  2023-06-01      2023  \r\nOp een goede  locatie  in de  kop van  het...
# 29 2022-09-01      2022        83 2022-09-22
# 30 2023-07-01      2023        22 2023-07-14
# 31 2023-07-01      2023        17 2023-07-10
# 32 2023-07-01      2023        19 2023-07-05
# 33 2023-06-01      2023        11 2023-06-28
# 34 2023-07-01      2023        23 2023-07-12
# 35 2022-09-01      2022        70 2022-09-09
# 36 2023-07-01      2023        25 2023-07-17
# 37 2023-06-01      2023         6 2023-06-28
# 38 2023-06-01      2023        15 2023-06-28
# 39 2023-07-01      2023        17 2023-07-07
# 40 2023-07-01      2023        15 2023-07-14
# 41 2023-07-01      2023        16 2023-07-15
# 42 2022-10-01      2022       109 2022-10-18
# 43 2023-07-01      2023        18 2023-07-17
# 44 2022-10-01      2022       122 2022-10-31
# 45 2023-07-01      2023        15 2023-07-12
# 46 2022-09-01      2022        63 2022-09-08
# 47 2023-07-01      2023        17 2023-07-07
# 48 2023-07-01      2023        14 2023-07-05
# 49 2022-09-01      2022        80 2022-09-19
# 50 2023-07-01      2023       244 2023-07-20
# 51 2023-03-01      2023       252 2023-03-10
# 52 2023-06-01      2023        15 2023-06-30
# 53 2023-07-01      2023        20 2023-07-03
# 54 2023-02-01      2023       672 2023-02-24
# 55 2022-09-01      2022        79 2022-09-18
# 56 2023-04-01      2023       145 2023-04-12
# 57 2023-04-01      2023       161 2023-04-28
# 58 2022-09-01      2022        79 2022-09-18
# 59 2023-07-01      2023        16 2023-07-17
#
# [60 rows x 25 columns]

# %%
raw

# %%
scraper.raw_df.iloc[0,:]

# %%
url = "https://www.funda.nl/koop/verkocht/huissen/huis-42953772-de-landheren-type-ii-bouwnr-6/"
response = requests.get(url, headers=config.header)
soup = BeautifulSoup(response.text, "lxml")

# %%
soup.select(".object-header__title")[0].text

# %%
import re

x = '\n5 rooms (3 bedrooms)\n'
result = re.findall("(\d{1,2}\s{1}slaapkamers{0,1})|(\d{1,2}\s{1}bedrooms{0,1})", x)
if len(result) > 0:
    result = "".join(result[0])
    x = result.split(' ')[0]
else:
    x = 0

x

# %%
""result[0]

# %%
result

# %%
def find_n_

# %%
soup.select(".object-kenmerken-list:nth-child(11) .fd-align-items-center:nth-child(4)")[0].text

# %%
x = '\n2 bathrooms en 1 apart toilet\n'

result = re.findall("(\d{1,2}\s{1}badkamers{0,1})|(\d{1,2}\s{1}bathrooms{0,1})", x)
if len(result) > 0:
    result = "".join(result[0])
    x = result.split(' ')[0]
else:
    x = 0
x

# %%
scraper.raw_df

# %%
"""Preprocess raw data scraped from Funda"""
from typing import Any

import pandas as pd
from funda_scraper.config.core import config
from datetime import datetime
from datetime import timedelta


def clean_price(x: str) -> int:
    """Clean the 'price' and transform from string to integer."""
    try:
        return int(str(x).split(" ")[1].replace(",", ""))
    except ValueError:
        return 0
    except IndexError:
        return 0


def clean_year(x: str) -> int:
    """Clean the 'year' and transform from string to integer"""
    if len(x) == 4:
        return int(x)
    elif x.find("-") != -1:
        return int(x.split("-")[0])
    elif x.find("before") != -1:
        return int(x.split(" ")[1])
    else:
        return 0


def clean_living_area(x: str) -> int:
    """Clean the 'living_area' and transform from string to integer"""
    try:
        return int(str(x).replace(",", "").split(" m²")[0])
    except ValueError:
        return 0
    except IndexError:
        return 0


def find_n_room(x: str) -> int:
    """Find the number of rooms from a string"""
    if x.find("room") != -1:
        return int(str(x).split("room")[0].strip())
    else:
        return 0


def find_n_bedroom(x: str) -> int:
    """Find the number of bedrooms from a string"""
    if x.find("bedroom") != -1:
        return int(x.split(" ")[2].replace("(", ""))
    else:
        return 0


def find_n_bathroom(x: str) -> int:
    """Find the number of bathrooms from a string"""
    if x.find("bathroom") != -1:
        return int(str(x).split("bathroom")[0].strip())
    else:
        return 0


def map_dutch_month(x: str) -> str:
    """Map the month from Dutch to English."""
    month_mapping = {
        "januari": "January",
        "februari": "February",
        "maart": "March",
        "mei": "May",
        "juni": "June",
        "juli": "July",
        "augustus": "August",
        "oktober": "October",
    }
    for k, v in month_mapping.items():
        if x.find(k) != -1:
            x = x.replace(k, v)
    return x


def get_neighbor(x: str) -> str:
    """Find the neighborhood name."""
    city = x.split("/")[0].replace("-", " ")
    return x.lower().split(city)[-1]


def clean_energy_label(x: str) -> str:
    """Clean the energy labels."""
    try:
        x = x.split(" ")[0]
        if x.find("A+") != -1:
            return ">A+"
        else:
            return x
    except IndexError:
        return x


def clean_list_date(x: str) -> Any:
    """Transform the date from string to datetime object."""

    def delta_now(d):
        t = timedelta(days=d)
        return datetime.now() - t

    try:
        if (
            x.find("€") != -1
            or x.find("na") != -1
            or x.find("Indefinite duration") != -1
        ):
            return "na"
        elif x.find("month") != -1:
            return delta_now(int(x.split("month")[0].strip()[0]) * 30)
        elif x.find("week") != -1:
            return delta_now(int(x.split("month")[0].strip()[0]) * 7)
        elif x.find("Today") != -1:
            return delta_now(1)
        elif x.find("day") != -1:
            return delta_now(int(x.split("month")[0].strip()))
        else:
            return datetime.strptime(x, "%B %d, %Y")
    except ValueError:
        return "na"


def preprocess_data(df: pd.DataFrame, is_past: bool) -> pd.DataFrame:
    """
    Clean the raw dataframe from scraping.
    Indicate whether it includes historical data sicne the columns would be different.

    :param df: raw dataframe from scraping
    :param is_past: whether it scraped past data
    :return: clean dataframe
    """

    df = df.dropna()
    keep_cols = config.keep_cols.selling_data
    keep_cols_sold = keep_cols + config.keep_cols.sold_data

    # Info
    df["house_id"] = df["url"].apply(lambda x: int(x.split("/")[-2].split("-")[1]))
    df["house_type"] = df["url"].apply(lambda x: x.split("/")[-2].split("-")[0])
    df = df[df["house_type"].isin(["appartement", "huis"])]

    # Price
    price_col = "price_sold" if is_past else "price"
    df["price"] = df[price_col].apply(clean_price)
    df = df[df["price"] != 0]
    df["living_area"] = df["living_area"].apply(clean_living_area)
    df = df[df["living_area"] != 0]
    df["price_m2"] = round(df.price / df.living_area, 1)

    # Location
    df["zip"] = df["zip_code"].apply(lambda x: x[:4])

    # House layout
    df["room"] = df["num_of_rooms"].apply(find_n_room)
    df["bedroom"] = df["num_of_rooms"].apply(find_n_bedroom)
    df["bathroom"] = df["num_of_bathrooms"].apply(find_n_bathroom)
    df["energy_label"] = df["energy_label"].apply(clean_energy_label)
    df["has_balcony"] = df["exteriors"].apply(
        lambda x: 1 if str(x).find("Balcony present") != -1 else 0
    )
    df["has_garden"] = df["exteriors"].apply(
        lambda x: 1 if str(x).find("garden") != -1 else 0
    )

    # Time
    df["year_built"] = df["year"].apply(clean_year).astype(int)
    df["house_age"] = 2023 - df["year_built"]

    if not is_past:
        # Only check current data
        df["date_list"] = df.listed_since.apply(clean_list_date)
        df = df[df["date_list"] != "na"]
        df["date_list"] = pd.to_datetime(df["date_list"])

    else:
        # Only check past data
        df = df[(df["date_sold"] != "na") & (df["date_list"] != "na")]
        df["date_sold"] = df["date_sold"].apply(map_dutch_month)
        df = df.dropna()
        df["date_list"] = pd.to_datetime(df["date_list"])
        df["date_sold"] = pd.to_datetime(df["date_sold"])
        df["ym_sold"] = df["date_sold"].apply(lambda x: x.to_period("M").to_timestamp())
        df["year_sold"] = df["date_sold"].apply(lambda x: x.year)

        # Term
        df["term_days"] = df["date_sold"] - df["date_list"]
        df["term_days"] = df["term_days"].apply(lambda x: x.days)
        keep_cols = keep_cols_sold

    df["ym_list"] = df["date_list"].apply(lambda x: x.to_period("M").to_timestamp())
    df["year_list"] = df["date_list"].apply(lambda x: x.year)

    return df[keep_cols].reset_index(drop=True)

# %%
df = scraper.raw_df

df

# %%
x = "€ 325.000 k.k."
int(str(x).split(" ")[1].replace(".", ""))

# %%
def clean_price(x: str) -> int:
    """Clean the 'price' and transform from string to integer."""
    try:
        return int(str(x).split(" ")[1].replace(".", ""))
    except ValueError:
        return 0
    except IndexError:
        return 0
    
    
df = scraper.raw_df
is_past = False

df = df.dropna()
keep_cols = config.keep_cols.selling_data
keep_cols_sold = keep_cols + config.keep_cols.sold_data

# Info
df["house_id"] = df["url"].apply(lambda x: int(x.split("/")[-2].split("-")[1]))
df["house_type"] = df["url"].apply(lambda x: x.split("/")[-2].split("-")[0])
df = df[df["house_type"].isin(["appartement", "huis"])]

# Price
price_col = "price_sold" if is_past else "price"
df["price"] = df[price_col].apply(clean_price)
# df = df[df["price"] != 0]
df["living_area"] = df["living_area"].apply(clean_living_area)
# df = df[df["living_area"] != 0]
df["price_m2"] = round(df.price / df.living_area, 1)

# Location
df["zip"] = df["zip_code"].apply(lambda x: x[:4])

# # House layout
df["room"] = df["num_of_rooms"].apply(find_n_room)
df["bedroom"] = df["num_of_rooms"].apply(find_n_bedroom)
df["bathroom"] = df["num_of_bathrooms"].apply(find_n_bathroom)
df["energy_label"] = df["energy_label"].apply(clean_energy_label)
df["has_balcony"] = df["exteriors"].apply(
    lambda x: 1 if str(x).find("Balcony present") != -1 else 0
)
df["has_garden"] = df["exteriors"].apply(
    lambda x: 1 if str(x).find("garden") != -1 else 0
)

# Time
df["year_built"] = df["year"].apply(clean_year).astype(int)
df["house_age"] = 2023 - df["year_built"]

# if not is_past:
#     # Only check current data
#     df["date_list"] = df.listed_since.apply(clean_list_date)
#     df = df[df["date_list"] != "na"]
#     df["date_list"] = pd.to_datetime(df["date_list"])

# else:
#     # Only check past data
#     df = df[(df["date_sold"] != "na") & (df["date_list"] != "na")]
#     df["date_sold"] = df["date_sold"].apply(map_dutch_month)
#     df = df.dropna()
#     df["date_list"] = pd.to_datetime(df["date_list"])
#     df["date_sold"] = pd.to_datetime(df["date_sold"])
#     df["ym_sold"] = df["date_sold"].apply(lambda x: x.to_period("M").to_timestamp())
#     df["year_sold"] = df["date_sold"].apply(lambda x: x.year)

#     # Term
#     df["term_days"] = df["date_sold"] - df["date_list"]
#     df["term_days"] = df["term_days"].apply(lambda x: x.days)
#     keep_cols = keep_cols_sold

# df["ym_list"] = df["date_list"].apply(lambda x: x.to_period("M").to_timestamp())
# df["year_list"] = df["date_list"].apply(lambda x: x.year)

df.head()

# %%
scraper = FundaScraper(area="amsterdam", want_to="buy", find_past=True, n_pages=1)
scraper.fetch_all_links()

# %%
x = "22 juli 2023"
parsed_date = parse(x, fuzzy=True)

parsed_date

# %%
df.listed_since

# %%
df['date_list'] = df.listed_since.map(clean_list_date)
df["date_list"] = pd.to_datetime(df["date_list"])
df['date_list']

# %%
df["ym_list"] = df["date_list"].apply(lambda x: x.to_period("M").to_timestamp())
df["year_list"] = df["date_list"].apply(lambda x: x.year)

# %%
df['listed_since']

# %%
from dateutil.parser import parse


def clean_list_date(x: str) -> Any:
    """Transform the date from string to datetime object."""

    def delta_now(d: int):
        t = timedelta(days=d)
        return datetime.now() - t

    
    weekdays_dict = {
    "maandag": "Monday",
    "dinsdag": "Tuesday",
    "woensdag": "Wednesday",
    "donderdag": "Thursday",
    "vrijdag": "Friday",
    "zaterdag": "Saturday",
    "zondag": "Sunday"
    }


    try:
        if  x.lower() in weekdays_dict.keys():
            date_string = weekdays_dict.get(x.lower())
            parsed_date = parse(date_string, fuzzy=True)
            delta = datetime.now().weekday() - parsed_date.weekday()
            return delta_now(delta)
    
        elif (
            x.find("€") != -1
            or x.find("na") != -1
            or x.find("Indefinite duration") != -1
        ):
            return "na"
        elif x.find("month") != -1:
            return delta_now(int(x.split("month")[0].strip()[0]) * 30)
        elif x.find("week") != -1:
            return delta_now(int(x.split("month")[0].strip()[0]) * 7)
        elif x.find("Today") != -1 or x.find("Vandaag") != -1:
            return datetime.now().date()
        elif x.find("day") != -1:
            return delta_now(int(x.split("month")[0].strip()))
        else:
            return datetime.strptime(x, "%d %B %Y")
        
    except ValueError:
        return x

# %%
import re

# %%
datetime.now().date()

# %%
import locale

# Set the locale to Dutch
locale.setlocale(locale.LC_TIME, 'nl_NL')

# Input string
date_string = "22 juli 2023"

# Parse the string to get the datetime object
parsed_date = datetime.strptime(date_string, "%d %B %Y")

print(parsed_date)

# %%
df['date_list'] = df['date'].map(clean_list_date)

# %%
import re

x = "33 Indefinite duration"
pattern = "(€)|(na)|(Indefinite duration)"
len(re.findall(pattern, x))
